# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasMahfudz/DataScienceProject/blob/main/Project2_MCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/AnasMahfudz/Dataset/main/menu.csv')
data
# Out:
#                Category  ... Iron (% Daily Value)
# 0             Breakfast  ...                   15
# 1             Breakfast  ...                    8
# 2             Breakfast  ...                   10
# 3             Breakfast  ...                   15
# 4             Breakfast  ...                   10
# ..                  ...  ...                  ...
# 255  Smoothies & Shakes  ...                    8
# 256  Smoothies & Shakes  ...                   10
# 257  Smoothies & Shakes  ...                    6
# 258  Smoothies & Shakes  ...                    6
# 259  Smoothies & Shakes  ...                    4
#
# [260 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
categorical = ['Category']
numerical = ['Calories',
             'Calories from Fat',
             'Total Fat',
             'Total Fat (% Daily Value)',
             'Saturated Fat',
             'Saturated Fat (% Daily Value)',
             'Trans Fat',
             'Cholesterol',
             'Cholesterol (% Daily Value)',
             'Sodium',
             'Sodium (% Daily Value)',
             'Carbohydrates',
             'Carbohydrates (% Daily Value)',
             'Sugars',
             'Protein',
             'Vitamin A (% Daily Value)',
             'Vitamin C (% Daily Value)',
             'Calcium (% Daily Value)',
             'Iron (% Daily Value)']

# %%
fig = plt.figure(figsize = (15,10))
ax = data[categorical].value_counts()[::-1].plot(kind='barh',title='Category', fontsize=14)
plt.show()

# %%
fig, axes = plt.subplots(10,2, figsize=(34,94))
axes = [ax for axes_row in axes for ax in axes_row]

for i, col in enumerate(numerical):
    plot = sns.boxplot(data=data, y='Category', x=col, ax=axes[i])
plt.tight_layout()

# %%
Calories_df = pd.DataFrame({"Calories":data.Calories,
                      "Item":data.Item})

Chicken_Calories = data.query("Category == 'Chicken & Fish'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Chicken_Calories, x='Calories', y='Item',order=Chicken_Calories.sort_values('Calories',ascending = False).Item)

# %%
TotalFat_df = pd.DataFrame({"Total Fat":data['Total Fat'],
                      "Item":data.Item})
Chicken_Fat = data.query("Category == 'Chicken & Fish'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Chicken_Fat, x='Total Fat', y='Item',order=Chicken_Fat.sort_values('Total Fat',ascending = False).Item)

# %%
Protein_df = pd.DataFrame({"Protein":data['Protein'],
                      "Item":data.Item})
Chicken_Protein = data.query("Category == 'Chicken & Fish'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Chicken_Protein, x='Protein', y='Item',order=Chicken_Protein.sort_values('Protein',ascending = False).Item)

# %%
Sugar_df = pd.DataFrame({"Sugars":data.Sugars,
                      "Item":data.Item})
Smooties_Sugars = data.query("Category == 'Smoothies & Shakes'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Smooties_Sugars, x='Sugars', y='Item',order=Smooties_Sugars.sort_values('Sugars',ascending = False).Item)

# %%
Carbo_df = pd.DataFrame({"Carbohydrates":data.Carbohydrates,
                      "Item":data.Item})
Smoothies_Carbo = data.query("Category == 'Smoothies & Shakes'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Smoothies_Carbo, x='Carbohydrates', y='Item',order=Smoothies_Carbo.sort_values('Carbohydrates',ascending = False).Item)

# %%
Calcium_df = pd.DataFrame({"Calcium":data['Calcium (% Daily Value)'],
                      "Item":data.Item})
Smooties_Calcium = data.query("Category == 'Smoothies & Shakes'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Smooties_Calcium, x='Calcium (% Daily Value)', y='Item',order=Smooties_Calcium.sort_values('Calcium (% Daily Value)',ascending = False).Item)

# %%
Cholesterol_df = pd.DataFrame({"Cholesterol":data.Cholesterol,
                      "Item":data.Item})
Breakfast_Cholesterol = data.query("Category == 'Breakfast'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Breakfast_Cholesterol, x='Cholesterol', y='Item',order=Breakfast_Cholesterol.sort_values('Cholesterol',ascending = False).Item)

# %%
plt.figure(figsize=(17,14))
ax = sns.heatmap(data.corr(), annot=True, fmt = ".02f",cmap="coolwarm", mask=np.triu(data.corr()))
cbar = ax.collections[0].colorbar
cbar.set_ticks([0, .25, .50, .75, 1])
cbar.set_ticklabels(['0%', '25%','50%', '75%', '100%'])

# %%
print(data.describe())
# Out:
#           Calories  ...  Iron (% Daily Value)
# count   260.000000  ...            260.000000
# mean    368.269231  ...              7.734615
# std     240.269886  ...              8.723263
# min       0.000000  ...              0.000000
# 25%     210.000000  ...              0.000000
# 50%     340.000000  ...              4.000000
# 75%     500.000000  ...             15.000000
# max    1880.000000  ...             40.000000
#
# [8 rows x 21 columns]

# %%
lists=["Beef & Pork",
       "Chicken & Fish",
       "Beverages",
       "Snacks & Sides",
       "Desserts",
       "Breakfast",
       "Smoothies & Shakes"]

# %%
for list in lists:
    #items ascending=False
    items=data.query('Category == list').sort_values(by="Calories", ascending=False)
    items_custom=items.iloc[:,[1,3,5]]
    
    #items ascending=True
    items_t=data.query('Category == list').sort_values(by="Calories", ascending=True)
    items_custom_t=items_t.iloc[:,[1,3,5]]
    
    #Print Categories
    print(lists.index(list)+1,".",list)
    
    #Plotly Express
    import plotly.express as px
    p_express = px.scatter(items_custom, x="Total Fat",y='Calories', color="Item",size='Calories', 
                           template="plotly_dark",hover_name="Item")
    p_express.show()
    
    #Display Tables ranked by calories
    table=items_custom.iloc[:,[0,1]].sort_values(by="Calories", ascending=False).style.hide_index()
    #table=table.style.hide_index()
    display(table)
    
    #Matplotlib pyplot
    fig,ax=plt.subplots()
    x=items_custom_t.iloc[:,0]
    y=items_custom_t.iloc[:,1]
    ax.barh(x,y, tick_label=x)
    plt.show()
# Out:
# 1 . Beef & Pork
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f9f7acc9-78ae-46a5-aaa6-fe88e4c7645f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f9f7acc9-78ae-46a5-aaa6-fe88e4c7645f")) {
#                     Plotly.newPlot(
#                         'f9f7acc9-78ae-46a5-aaa6-fe88e4c7645f',
# ...

# %%
# Plotting the KDEplots
f, axes = plt.subplots(3, 3, figsize=(10, 10), sharex=True, sharey=True)

s = np.linspace(0, 3, 10)
cmap = sns.cubehelix_palette(start=0.0, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Cholesterol (% Daily Value)'].values
y = data['Sodium (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, cut=5, ax=axes[0,0])
axes[0,0].set(xlim=(-10, 50), ylim=(-30, 70), title = 'Cholesterol and Sodium')

cmap = sns.cubehelix_palette(start=0.333333333333, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Carbohydrates (% Daily Value)'].values
y = data['Sodium (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[0,1])
axes[0,1].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Carbs and Sodium')

cmap = sns.cubehelix_palette(start=0.666666666667, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Carbohydrates (% Daily Value)'].values
y = data['Cholesterol (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[0,2])
axes[0,2].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Carbs and Cholesterol')

cmap = sns.cubehelix_palette(start=1.0, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Total Fat (% Daily Value)'].values
y = data['Saturated Fat (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[1,0])
axes[1,0].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Total Fat and Saturated Fat')

cmap = sns.cubehelix_palette(start=1.333333333333, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Total Fat (% Daily Value)'].values
y = data['Cholesterol (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[1,1])
axes[1,1].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Cholesterol and Total Fat')

cmap = sns.cubehelix_palette(start=1.666666666667, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Vitamin A (% Daily Value)'].values
y = data['Cholesterol (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[1,2])
axes[1,2].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Vitamin A and Cholesterol')

cmap = sns.cubehelix_palette(start=2.0, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Calcium (% Daily Value)'].values
y = data['Sodium (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[2,0])
axes[2,0].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Calcium and Sodium')

cmap = sns.cubehelix_palette(start=2.333333333333, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Calcium (% Daily Value)'].values
y = data['Cholesterol (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[2,1])
axes[2,1].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Cholesterol and Calcium')

cmap = sns.cubehelix_palette(start=2.666666666667, light=1, as_cmap=True)

# Generate and plot a random bivariate dataset
x = data['Iron (% Daily Value)'].values
y = data['Total Fat (% Daily Value)'].values
sns.kdeplot(x, y, cmap=cmap, shade=True, ax=axes[2,2])
axes[2,2].set(xlim=(-5, 50), ylim=(-10, 70),  title = 'Iron and Total Fat')


f.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# ...
