# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasMahfudz/DataScienceProject/blob/main/Project1_Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Understanding

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/AnasMahfudz/Dataset/main/netflix_titles.csv')
data
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #2. Data Preprocessing

# %%
# Merubah format waktu (tanggal dan tahun)
data["date_added"] = pd.to_datetime(data['date_added'])
data['year_added'] = data['date_added'].dt.year
data['month_added'] = data['date_added'].dt.month
data
# Out:
#      show_id     type  ... year_added month_added
# 0         s1  TV Show  ...     2020.0         8.0
# 1         s2    Movie  ...     2016.0        12.0
# 2         s3    Movie  ...     2018.0        12.0
# 3         s4    Movie  ...     2017.0        11.0
# 4         s5    Movie  ...     2020.0         1.0
# ...      ...      ...  ...        ...         ...
# 7782   s7783    Movie  ...     2020.0        10.0
# 7783   s7784    Movie  ...     2019.0         3.0
# 7784   s7785    Movie  ...     2020.0         9.0
# 7785   s7786  TV Show  ...     2020.0        10.0
# 7786   s7787    Movie  ...     2020.0         3.0
#
# [7787 rows x 14 columns]

# %%
#Memisahkan Duration movie dan TV Show (Season)
data['season_count'] = data.apply(lambda x : x['duration'].split(" ")[0] if "Season" in x['duration'] else "", axis = 1)
data['duration'] = data.apply(lambda x : x['duration'].split(" ")[0] if "Season" not in x['duration'] else "", axis = 1)
data
# Out:
#      show_id     type  ... month_added season_count
# 0         s1  TV Show  ...         8.0            4
# 1         s2    Movie  ...        12.0
# 2         s3    Movie  ...        12.0
# 3         s4    Movie  ...        11.0
# 4         s5    Movie  ...         1.0
# ...      ...      ...  ...         ...          ...
# 7782   s7783    Movie  ...        10.0
# 7783   s7784    Movie  ...         3.0
# 7784   s7785    Movie  ...         9.0
# 7785   s7786  TV Show  ...        10.0            1
# 7786   s7787    Movie  ...         3.0
#
# [7787 rows x 15 columns]

# %%
#Merubah listed_in menjadi genre
data=data.rename(columns={'listed_in':'genre'})
data['genre'] = data['genre'].apply(lambda x: x.split(",")[0])
data
# Out:
#      show_id     type  ... month_added season_count
# 0         s1  TV Show  ...         8.0            4
# 1         s2    Movie  ...        12.0
# 2         s3    Movie  ...        12.0
# 3         s4    Movie  ...        11.0
# 4         s5    Movie  ...         1.0
# ...      ...      ...  ...         ...          ...
# 7782   s7783    Movie  ...        10.0
# 7783   s7784    Movie  ...         3.0
# 7784   s7785    Movie  ...         9.0
# 7785   s7786  TV Show  ...        10.0            1
# 7786   s7787    Movie  ...         3.0
#
# [7787 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genre              0
# description        0
# year_added        10
# month_added       10
# season_count       0
# dtype: int64

# %%
data.describe()
# Out:
#        release_year   year_added  month_added
# count   7787.000000  7777.000000  7777.000000
# mean    2013.932580  2018.493378     6.783850
# std        8.757395     1.388144     3.591608
# min     1925.000000  2008.000000     1.000000
# 25%     2013.000000  2018.000000     4.000000
# 50%     2017.000000  2019.000000     7.000000
# 75%     2018.000000  2020.000000    10.000000
# max     2021.000000  2021.000000    12.000000

# %% [markdown]
# #3. Data Visualization

# %%
categorical_columns = ['type',
                       'rating',
                       'genre',
                       'year_added',
                       'season_count']

# %%
import matplotlib.pyplot as plt


fig, axes = plt.subplots(6,1, figsize=(11,25))
#axes = [ax for axes_row in axes for ax in axes_row]

for i, col in enumerate(categorical_columns):
  data[col].value_counts()[::-1].plot(kind='barh',ax=axes[i], title=col, fontsize=14)
  axes[i].set_ylabel('')
plt.tight_layout()

# %%
fig = plt.figure(figsize = (15,10))
ax = data['genre'].value_counts()[::-1].plot(kind='barh',title='genre', fontsize=14)
plt.show()

# %%
data['genre'].value_counts()
# Out:
# Dramas                          1384
# Comedies                        1074
# Documentaries                    751
# Action & Adventure               721
# International TV Shows           690
# Children & Family Movies         502
# Crime TV Shows                   369
# Kids' TV                         359
# Stand-Up Comedy                  321
# Horror Movies                    244
# British TV Shows                 232
# Docuseries                       194
# Anime Series                     148
# International Movies             114
# TV Comedies                      110
# Reality TV                       102
# Classic Movies                    77
# TV Dramas                         62
# Movies                            56
# Thrillers                         49
# TV Action & Adventure             37
# Stand-Up Comedy & Talk Shows      33
# Romantic TV Shows                 28
# Classic & Cult TV                 21
# Independent Movies                20
# ...

# %%
import seaborn as sns
Drama = pd.DataFrame({"type":data.type,
                      'valuecount':data.query["genre == 'Dramas'"].value_counts()})

Drama_Show = data.query("genre == 'Dramas'")
plt.figure(figsize=(15,8))
ax = sns.barplot(data=Drama, x='valuecount', y='type', order=Drama_Show.type)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-a27c64cb2630> in <module>()
#       1 import seaborn as sns
#       2 Drama = pd.DataFrame({"type":data.type,
# ----> 3                       'valuecount':data.query["genre == 'Dramas'"].value_counts()})
#       4
#       5 Drama_Show = data.query("genre == 'Dramas'")
#
# TypeError: 'method' object is not subscriptable
